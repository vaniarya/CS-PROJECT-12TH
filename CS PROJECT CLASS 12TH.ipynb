# %% [markdown]
# # CS PROJECT
# CLASS: XII-A
# NAME: Vani Arya

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import csv
def bookwrite(a):
    f= open("C:\\Users\\User\\OneDrive\\Desktop\\Book_Dataset_11.csv", 'a', encoding='utf-8')
    d= csv.writer(f)
    for i in range(a): 
        cp= int(input('sno'))
        t= input('Enter title of the book')
        c= input('enter category of the book')
        pr= float(input('enter price of the book'))
        pr_t= float(input('enter price of the book after tax'))
        tax= pr= float(input('enter tax amount'))
        aval= int(input('availability of the book'))
        rev= int(input('no. of reviews'))
        desc= input('book discription')
        link= input('link of book cover')
        rate= int(input('enter ratings of the book'))
        d.writerow([cp,t,c,pr,pr_t,tax,aval,rev,desc,link,rate,])
    f.close()

def booksearch():
    f= open("C:\\Users\\User\\OneDrive\\Desktop\\Book_Dataset_11.csv", 'r', encoding='utf-8')
    d= csv.reader(f)
    a= input('enter what type of book you prefer:\n 1. book name \n 2. author \n 3. genre\n 4.ratings ')
    for i in d:
        if a in i:
            print (i)
    f.close()
    
def bookread():
    f= open("C:\\Users\\User\\OneDrive\\Desktop\\Book_Dataset_11.csv", 'r', encoding='utf-8')
    d= csv.reader(f)
    for i in d:
        print(i)
    f.close()

#MAIN
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread("C:\\Users\\User\\OneDrive\\Pictures\\top-10-books-every-college-student-read-1024x640.jpeg")
plt.imshow(img)
print('Welcome to BookMania\n Are you having trouble finding which book you should read next?\n don\'t worry!!!\n here at BookMania you will find 1000+ books of all genres')
#while True:
print('MENU\n 1- Read\n 2- Write \n 3- Search\n 4-Exit')
ch= int(input("enter your choice"))
while True:
    if ch==1:
        bookread()
        break
    elif ch==2:
        a= int(input('How many records you want to enter: '))
        bookwrite(a)
        break
    elif ch==3:
        booksearch()
        break
    elif ch==4:
        print('***END OF PROGRAM***')
        break
# Out:
# Welcome to BookMania
#  Are you having trouble finding which book you should read next?
#  don't worry!!!
#  here at BookMania you will find 1000+ books of all genres
# MENU
#  1- Read
#  2- Write
#  3- Search
#  4-Exit
# enter your choice4
# ***END OF PROGRAM***
